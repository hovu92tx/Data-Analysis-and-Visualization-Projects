# %%
import pandas as pd 

df = pd.read_csv("US Airline Flight Routes and Fares.csv")
df.head()
# Out:
# C:\Users\hovu9\AppData\Local\Temp\ipykernel_22116\1154185420.py:3: DtypeWarning: Columns (20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("US Airline Flight Routes and Fares.csv")
#        tbl  Year  quarter  citymarketid_1  citymarketid_2  \
# 0  Table1a  2021        3           30135           33195
# 1  Table1a  2021        3           30135           33195
# 2  Table1a  2021        3           30140           30194
# 3  Table1a  2021        3           30140           30194
# 4  Table1a  2021        3           30140           30466
#
#                             city1                          city2  airportid_1  \
# 0  Allentown/Bethlehem/Easton, PA  Tampa, FL (Metropolitan Area)        10135
# 1  Allentown/Bethlehem/Easton, PA  Tampa, FL (Metropolitan Area)        10135
# 2                 Albuquerque, NM          Dallas/Fort Worth, TX        10140
# ...

# %%
for col in df.columns:
    print(col)
# Out:
# tbl
# Year
# quarter
# citymarketid_1
# citymarketid_2
# city1
# city2
# airportid_1
# airportid_2
# airport_1
# airport_2
# nsmiles
# passengers
# fare
# carrier_lg
# large_ms
# fare_lg
# carrier_low
# lf_ms
# fare_low
# Geocoded_City1
# Geocoded_City2
# tbl1apk

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245955 entries, 0 to 245954
# Data columns (total 23 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tbl             245955 non-null  object
#  1   Year            245955 non-null  int64
#  2   quarter         245955 non-null  int64
#  3   citymarketid_1  245955 non-null  int64
#  4   citymarketid_2  245955 non-null  int64
#  5   city1           245955 non-null  object
#  6   city2           245955 non-null  object
#  7   airportid_1     245955 non-null  int64
#  8   airportid_2     245955 non-null  int64
#  9   airport_1       245955 non-null  object
#  10  airport_2       245955 non-null  object
#  11  nsmiles         245955 non-null  int64
#  12  passengers      245955 non-null  int64
#  13  fare            245955 non-null  float64
#  14  carrier_lg      244415 non-null  object
#  15  large_ms        244415 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# tbl                   0
# Year                  0
# quarter               0
# citymarketid_1        0
# citymarketid_2        0
# city1                 0
# city2                 0
# airportid_1           0
# airportid_2           0
# airport_1             0
# airport_2             0
# nsmiles               0
# passengers            0
# fare                  0
# carrier_lg         1540
# large_ms           1540
# fare_lg            1540
# carrier_low        1612
# lf_ms              1612
# fare_low           1612
# Geocoded_City1    39206
# Geocoded_City2    39206
# tbl1apk               0
# dtype: int64

# %%
df.isna().sum()
# Out:
# tbl                   0
# Year                  0
# quarter               0
# citymarketid_1        0
# citymarketid_2        0
# city1                 0
# city2                 0
# airportid_1           0
# airportid_2           0
# airport_1             0
# airport_2             0
# nsmiles               0
# passengers            0
# fare                  0
# carrier_lg         1540
# large_ms           1540
# fare_lg            1540
# carrier_low        1612
# lf_ms              1612
# fare_low           1612
# Geocoded_City1    39206
# Geocoded_City2    39206
# tbl1apk               0
# dtype: int64

# %%
df.dropna(axis=0, inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 205189 entries, 5919 to 222942
# Data columns (total 23 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tbl             205189 non-null  object
#  1   Year            205189 non-null  int64
#  2   quarter         205189 non-null  int64
#  3   citymarketid_1  205189 non-null  int64
#  4   citymarketid_2  205189 non-null  int64
#  5   city1           205189 non-null  object
#  6   city2           205189 non-null  object
#  7   airportid_1     205189 non-null  int64
#  8   airportid_2     205189 non-null  int64
#  9   airport_1       205189 non-null  object
#  10  airport_2       205189 non-null  object
#  11  nsmiles         205189 non-null  int64
#  12  passengers      205189 non-null  int64
#  13  fare            205189 non-null  float64
#  14  carrier_lg      205189 non-null  object
#  15  large_ms        205189 non-null  float64
# ...

# %%
df.head()
# Out:
#            tbl  Year  quarter  citymarketid_1  citymarketid_2  \
# 5919  Table 1a  2010        1           34614           33195
# 5920  Table 1a  1998        4           30189           31703
# 5921  Table 1a  1998        4           30198           30852
# 5922  Table 1a  2009        3           32211           32575
# 5923  Table 1a  1993        4           30255           30852
#
#                      city1                                  city2  \
# 5919    Salt Lake City, UT          Tampa, FL (Metropolitan Area)
# 5920  Colorado Springs, CO  New York City, NY (Metropolitan Area)
# 5921        Pittsburgh, PA     Washington, DC (Metropolitan Area)
# 5922         Las Vegas, NV    Los Angeles, CA (Metropolitan Area)
# 5923        Huntsville, AL     Washington, DC (Metropolitan Area)
#
#       airportid_1  airportid_2 airport_1  ...    fare  carrier_lg  large_ms  \
# 5919        14869        15304       SLC  ...  226.59          DL      0.38
# ...

# %%
df.drop(['tbl', 'Geocoded_City1', 'Geocoded_City2'],axis=1, inplace=True)

# %%
df.head()
# Out:
#       Year  quarter  citymarketid_1  citymarketid_2                 city1  \
# 5919  2010        1           34614           33195    Salt Lake City, UT
# 5920  1998        4           30189           31703  Colorado Springs, CO
# 5921  1998        4           30198           30852        Pittsburgh, PA
# 5922  2009        3           32211           32575         Las Vegas, NV
# 5923  1993        4           30255           30852        Huntsville, AL
#
#                                       city2  airportid_1  airportid_2  \
# 5919          Tampa, FL (Metropolitan Area)        14869        15304
# 5920  New York City, NY (Metropolitan Area)        11109        12197
# 5921     Washington, DC (Metropolitan Area)        14122        10821
# 5922    Los Angeles, CA (Metropolitan Area)        12889        14908
# 5923     Washington, DC (Metropolitan Area)        12217        12264
#
#      airport_1 airport_2  nsmiles  passengers    fare carrier_lg  large_ms  \
# ...
